# %% [markdown]
# # שבוע 5 — מבני נתונים
#
# בשבוע השישי נלמד על מבני נתונים חשובים נוספים שמרחיבים את יכולות התכנות שלנו,
# ונראה כיצד ניתן **לשמור, לארגן ולשלוף מידע** בצורה גמישה ונוחה.
# נכיר מבני נתונים כמו tuples ומילונים (dictionaries), ונלמד מתי להשתמש בכל אחד מהם.
#
# נוסיף לכך גם עבודה עם קבצים – איך לקרוא נתונים מקובץ טקסט או לשמור אליהם תוצאות,
# וכן איך לעצב מחרוזות בעזרת כלים מתקדמים ליצירת פלט נקי וברור.
#
# בסוף השבוע תדעו:
# - להבין את ההבדלים בין מבני נתונים שונים
# - ליצור ולהשתמש ב-tuples ומילונים
#
# ## Materials
# - {doc}`1 חזרה: אובייקטים ניתנים לשינוי ובלתי־ניתנים לשינוי <../../vendor/virtual-pyprog/10_0_mutable-vs-immutable>`
# - {doc}`2 שימושים מתקדמים בפונקציות <../../vendor/virtual-pyprog/11_0_advanced_function_usage>`
# - {doc}`3 מבוא למבני נתונים <../../vendor/virtual-pyprog/12_0_data_structures>`
# - {doc}`4 רשומות (Tuples) <../../vendor/virtual-pyprog/12_1_tuples>`
# - {doc}`5 מילונים (Dictionaries) <../../vendor/virtual-pyprog/12_2_dicts>`
# <!-- - {doc}`5 • עיצוב מחרוזות (String Formats) <../../vendor/virtual-pyprog/13_0_string-formats>` -->

# %%
import sys, os
try:
    _d = os.path.dirname(os.path.abspath(__vsc_ipynb_file__))
except NameError:
    _d = os.getcwd()
while _d != os.path.dirname(_d):
    if os.path.exists(os.path.join(_d, '_config.yml')): break
    _d = os.path.dirname(_d)
if _d not in sys.path: sys.path.insert(0, _d)
from ai_widget_loader import load_ai_widget
load_ai_widget()
