# %% [markdown]
# # שבוע 12 — Pandas: עבודה על טבלאות
#
# בשבוע האחד עשר נכיר את **Pandas**, הכלי המרכזי לעיבוד וניתוח נתונים.
#
# נלמד את עקרונות העבודה עם **Pandas** – איך לחשוב על נתונים בצורה טבלאית,
# מהם מבני הנתונים המרכזיים שלה, ואיך לייבא נתונים ממקורות שונים לקובצי DataFrame.
#
# בסוף השבוע תדעו:
# - ליצור ולעבוד עם מבני הנתונים `Series` ו־`DataFrame`
# - לייבא ולייצא נתונים
# - לבצע פעולות בסיסיות על טבלאות כמו גישה לשורות ועמודות, הוספה ומחיקה של תוכן מטבלה
#
# ## Materials
# - {doc}`1 • מבוא לPandas <../../vendor/virtual-pyprog/19_1_pandas-intro>`
# - {doc}`2 • יצירת טבלה <../../vendor/virtual-pyprog/19_1_pandas-intro>`
# - {doc}`3 • גישה לנתונים בטבלה <../../vendor/virtual-pyprog/19_1_pandas-intro>`
# - {doc}`4 • ביצוע פעולות בטבלה <../../vendor/virtual-pyprog/19_1_pandas-intro>`

# %%
import sys, os
try:
    _d = os.path.dirname(os.path.abspath(__vsc_ipynb_file__))
except NameError:
    _d = os.getcwd()
while _d != os.path.dirname(_d):
    if os.path.exists(os.path.join(_d, '_config.yml')): break
    _d = os.path.dirname(_d)
if _d not in sys.path: sys.path.insert(0, _d)
from ai_widget_loader import load_ai_widget
load_ai_widget()
