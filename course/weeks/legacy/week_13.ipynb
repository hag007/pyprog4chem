# %% [markdown]
# # שבוע 12 — עיבוד וניתוח נתונים עם Pandas (המשך)
#
# בשבוע האחד־עשר נעמיק בעבודה עם **Pandas** –
# נלמד כיצד למיין, לסנן, לקבץ ולעצב נתונים בצורה יעילה,
# לבצע חישובים וקטוריים, וליצור תובנות ויזואליות מהירות מתוך הנתונים.
#
# נבין כיצד להשתמש במבני הנתונים של הספרייה כדי לבצע
# טרנספורמציות, חיבורים בין טבלאות, ועיבוד נתוני זמן.
#
# בסוף השבוע תדעו:
# - לבחור, למיין ולסנן נתונים לפי תנאים שונים
# - לנקות נתונים ולזהות סוגי משתנים בצורה יעילה
# - לבצע טרנספורמציות ווקטוריות ולחשב עמודות חדשות
# - לקבץ נתונים (`groupby`) ולחשב סטטיסטיקות
# - לעצב מחדש טבלאות (`pivot`, `melt`) ולמזג כמה מקורות מידע
# - לעבוד עם נתוני זמן (`DatetimeIndex`, `resample`)
# - להפיק תובנות מהירות בעזרת שרטוטים בסיסיים מתוך Pandas
#
# ## Materials
# - {doc}`1 • מיון, סינון ואינדוקס נתונים <../../course/weeks/week_11/11_3_indexing_select_filter>`
# - {doc}`2 • ניקוי נתונים וטיפול בסוגי עמודות <../../course/weeks/week_11/11_4_cleaning_type_handling>`
# - {doc}`3 • טרנספורמציות וקטוריות <../../course/weeks/week_11/11_5_vector_transform>`
# - {doc}`4 • קיבוץ וצבירה (Grouping & Aggregation) <../../course/weeks/week_11/11_6_grouping_aggregation>`
# - {doc}`5 • עיצוב מחדש של טבלאות (Reshaping) <../../course/weeks/week_11/11_7_reshaping_dataframes>`
# - {doc}`6 • מיזוג וחיבור בין טבלאות (Merging & Joining) <../../course/weeks/week_11/11_8_merging_joining>`
# - {doc}`7 • עבודה עם סדרות זמן (Time Series) <../../course/weeks/week_11/11_9_time_series>`
# - {doc}`8 • חקירת נתונים ושרטוטים מהירים <../../course/weeks/week_11/11_10_exploration_quick_plots>`
