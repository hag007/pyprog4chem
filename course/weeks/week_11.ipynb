# %% [markdown]
# # שבוע 11 — חישובים מדעיים עם SciPy
#
# בשבוע ה-11 נצלול אל הספרייה **SciPy**, אחת מאבני היסוד של מדעי הנתונים והחישוב בפייתון,
#
#
# נלמד כיצד לבצע אינטגרציה, אופטימיזציה, אינטרפולציה, ולעבוד עם קבועים פיזיקליים –
# כלים קריטיים לכל כימאי, מהנדס או חוקר העוסק בנתונים אמפיריים ובמודלים מתמטיים.
#
# נבין כיצד ניתן להשתמש ב־SciPy כדי:
# - לגשת לקבועים פיזיקליים מדויקים כמו $c, G, h$ ולתרגם יחידות בין מערכות שונות
# - לחשב אינטגרלים של פונקציות (חד־ממדיים ורב־ממדיים) בצורה נומרית
# - למצוא מינימום ומקסימום של פונקציות באמצעות שיטות אופטימיזציה מתקדמות
#
# ## Materials
# - {doc}`1 • קבועים פיזיקליים ויחידות <../../course/weeks/week_11/11_1_physical_consts>`
# - {doc}`2 • אינטגרציה נומרית <../../course/weeks/week_11/11_2_integration>`
# - {doc}`3 • אופטימיזציה <../../course/weeks/week_11/11_3_optimization>`
# - {doc}`4 • תרגול: התפלגות Maxwell-Boltzmann <../../course/weeks/week_11/11_5_example_MB>`
