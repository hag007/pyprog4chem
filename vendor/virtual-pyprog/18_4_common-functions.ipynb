# %%
import urllib.request
import zipfile
import os
import ssl

try:
    os.mkdir("files")
except:
    pass

ssl._create_default_https_context = ssl._create_unverified_context

with urllib.request.urlopen('https://courses.cs.tau.ac.il/pyProg/2526a/resources/notebook_resources.zip') as f:
    content = f.read()

with open('files/notebook_resources.zip', 'wb') as f:
    f.write(content)

with zipfile.ZipFile('files/notebook_resources.zip', 'r') as zip_ref:
    zip_ref.extractall('files')

print(os.listdir('files'))
# Out:
# ['baby.png', 'countries-of-the-world.csv', 'dialation.png', 'dialation_2.png', 'dog.png', 'dog_noised.png', 'erosion.png', 'erosion_2.png', 'evil_morty_1.png', 'evil_morty_change.png', 'evil_morty_change_3.png', 'evil_morty_change_noised.png', 'evil_morty_segmentation.png', 'ex1.csv', 'ex2.csv', 'foods.txt', 'infile1.txt', 'infile2.txt', 'koala.png', 'monday.txt', 'notebook_resources.zip', 'orders_2_2024.csv', 'orders_3_2024.csv', 'orders_4_2024.csv', 'out.txt', 'products2.csv', 'ship.png', 'StudentsGrades.csv', 'sunday.txt', 'witcher_1.csv', 'witcher_2.csv', 'woman_noised.png', '__MACOSX']

# %% [markdown]
# **שימו לב**: על מנת להריץ את התאים ב-Live Code, יש לייבא תחילה את ספרית `numpy` ע"י הרצת השורת הבאה:

# %%
import numpy as np

# %% [markdown]
# # סיכום פונקציות נפוצות ב`numpy`

# %% [markdown]
# | category | name | use |
# |:--------:|:-----|:----|
# |**Creation**| | |
# | | [np.array(obj)](https://numpy.org/doc/stable/reference/generated/numpy.array.html) | create a new ndarray from an object like a list or tuple |
# | | [np.zeros(shape, dtype)](https://numpy.org/doc/stable/reference/generated/numpy.zeros.html) | create a new ndarray filled with zeros |
# | | [np.ones(shape, dtype)](https://numpy.org/doc/stable/reference/generated/numpy.ones.html) | create a new ndarray filled with ones |
# | | [np.arange(start, stop, step)](https://numpy.org/doc/stable/reference/generated/numpy.arange.html) | create an ndarray with evenly spaced values |
# | | [np.random.random(size)](https://numpy.org/doc/stable/reference/random/generated/numpy.random.random.html) | create an ndarray with random floats in [0, 1) |
# | | [np.random.randint(low, high, size)](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html) | create an ndarray with random integers in a given range |
# |**Typing**| | |
# | | [np.uint8](https://numpy.org/devdocs/reference/arrays.scalars.html#numpy.uint8) | unsigned integer type between 0 and 255 |
# | | [np.int_](https://numpy.org/devdocs/reference/arrays.scalars.html#numpy.int_) | default integer type |
# |**Attribute access**| | |
# | | [array.shape](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.shape.html) | tuple describing the shape of the array |
# | | [array.T](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.T.html) | transpose of the array |
# |**Array manipulation**| | |
# | | [np.reshape(array, new_shape)](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html) | change the shape of an array without changing its data |
# | | [np.sort(array, axis)](https://numpy.org/doc/stable/reference/generated/numpy.sort.html) | return a sorted copy of an array |
# | | [np.clip(array, min, max)](https://numpy.org/doc/stable/reference/generated/numpy.clip.html) | limit values in an array to a given range |
# | | [np.hstack((a, b, ...))](https://numpy.org/doc/stable/reference/generated/numpy.hstack.html) | stack arrays horizontally (column wise) |
# | | [np.vstack((a, b, ...))](https://numpy.org/doc/stable/reference/generated/numpy.vstack.html) | stack arrays vertically (row wise) |
# |**Numerical operations**| | |
# | | [np.abs(array)](https://numpy.org/doc/stable/reference/generated/numpy.abs.html) | element wise absolute value |
# | | [np.log(array)](https://numpy.org/doc/stable/reference/generated/numpy.log.html) | natural logarithm, element wise |
# | | [np.log2(array)](https://numpy.org/doc/stable/reference/generated/numpy.log2.html) | base 2 logarithm, element wise |
# | | [np.log10(array)](https://numpy.org/doc/stable/reference/generated/numpy.log10.html) | base 10 logarithm, element wise |
# |**Aggregation**| | |
# | | [array.sum(axis)](https://numpy.org/doc/stable/reference/generated/numpy.sum.html) | sum of elements, optionally along an axis |
# | | [array.mean(axis)](https://numpy.org/doc/stable/reference/generated/numpy.mean.html) | mean of elements, optionally along an axis |
# | | [array.median(axis)](https://numpy.org/doc/stable/reference/generated/numpy.median.html) | median value, optionally along an axis |
# | | [array.max(axis)](https://numpy.org/doc/stable/reference/generated/numpy.max.html) | maximum value, optionally along an axis |
# | | [array.min(axis)](https://numpy.org/doc/stable/reference/generated/numpy.min.html) | minimum value, optionally along an axis |
# | | [array.argmax(axis)](https://numpy.org/doc/stable/reference/generated/numpy.argmax.html) | index of the maximum value |
# | | [array.argmin(axis)](https://numpy.org/doc/stable/reference/generated/numpy.argmin.html) | index of the minimum value |
# | | [np.maximum(a, b)](https://numpy.org/doc/stable/reference/generated/numpy.maximum.html) | element wise maximum between two arrays |
# | | [np.minimum(a, b)](https://numpy.org/doc/stable/reference/generated/numpy.minimum.html) | element wise minimum between two arrays |
# | | [array.any(axis)](https://numpy.org/doc/stable/reference/generated/numpy.any.html) | True if any element is True |
# | | [array.all(axis)](https://numpy.org/doc/stable/reference/generated/numpy.all.html) | True if all elements are True |
# | | [array.nonzero()](https://numpy.org/doc/stable/reference/generated/numpy.nonzero.html) | indices of non zero elements |
# | | [np.bincount(array, bins)](https://numpy.org/doc/stable/reference/generated/numpy.histogram.html) | compute histogram counts per bin |
